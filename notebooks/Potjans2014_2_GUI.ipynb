# %%
from pyNN import pynn2gui as sim

# %%
from sim_params import simulator_params
from network_params import *
import network

sim.setup(**simulator_params['nest'])
n = network.Network(sim)
n.setup(sim)
# Out:
# w: [[  2.77647979 -11.10591914   5.55295957 -11.10591914   2.77647979
#   -11.10591914   2.77647979 -11.10591914]
#  [  2.77647979 -11.10591914   2.77647979 -11.10591914   2.77647979
#   -11.10591914   2.77647979 -11.10591914]
#  [  2.77647979 -11.10591914   2.77647979 -11.10591914   2.77647979
#   -11.10591914   2.77647979 -11.10591914]
#  [  2.77647979 -11.10591914   2.77647979 -11.10591914   2.77647979
#   -11.10591914   2.77647979 -11.10591914]
#  [  2.77647979 -11.10591914   2.77647979 -11.10591914   2.77647979
#   -11.10591914   2.77647979 -11.10591914]
#  [  2.77647979 -11.10591914   2.77647979 -11.10591914   2.77647979
#   -11.10591914   2.77647979 -11.10591914]
#  [  2.77647979 -11.10591914   2.77647979 -11.10591914   2.77647979
#   -11.10591914   2.77647979 -11.10591914]
#  [  2.77647979 -11.10591914   2.77647979 -11.10591914   2.77647979
#   -11.10591914   2.77647979 -11.10591914]]
# creating connections from L23E to L23E
# creating connections from L23I to L23E
# ...

# %%
sim.network.net.xml_struct()
# Out:
# <?xml version="1.0" ?>
# <mxGraphModel>
#    <root>
#       <mxCell data_cell="{celltype: empty_no_edge}" id="0"/>
#       <mxCell data_cell="{celltype: empty_no_edge}" id="1" parent="0"/>
# ...
